# %%
from keras.models import load_model
model = load_model('/Birds&Flowers-classifier.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
from keras.preprocessing import image

# %%
img = image.load_img('/rose2.jpg',target_size = (64,64))

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
ig = ImageDataGenerator(rescale=1./255)

# %%
from keras.preprocessing.image import img_to_array
import numpy as np

# %%
img_array = img_to_array(img)
img_array = np.expand_dims(img_array,axis=0)
newing = ig.flow(img_array)

# %%
pred = model.predict(newing)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()

# %%
pred
# Out:
# array([[1.1954221e-07, 3.4902184e-10, 9.9999988e-01]], dtype=float32)

# %%
list(pred[0]).index(max(pred[0]))
# Out:
# 2

# %%
print("Birds" if pred[0][0]>0.5 else "Flowers")
# Out:
# Flowers
